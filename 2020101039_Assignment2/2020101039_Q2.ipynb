# %% [markdown]
# # Assignment 2 - Question 2
# The objective of this assignment is to get you familiarize with  the  problem  of  `Dimensionality Reduction`.
#
#
# ## Instructions
#
# - Write your code and analysis in the indicated cells.
# - Ensure that this notebook runs without errors when the cells are run in sequence.
# - Do not attempt to change the contents of other cells.
# - No inbuilt functions to be used until specified. Libraries allowed (Numpy, matplotlib)
#
# ## Datasets
# - The IIIT-CFW is database for the cartoon faces in the wild. The dataset contains 8928 annotated cartoon faces of famous personalities of the world with varying profession. Additional 1000 real faces of the public figure to study cross modal retrieval tasks, such as, Photo2Cartoon retrieval. Ref - https://cvit.iiit.ac.in/research/projects/cvit-projects/cartoonfaces
# - We have sub sampled the following data for this assignment - Cartoon faces of 8 subjects and approx. 100 images for each subject.
#
# ## Submission
# - Ensure that this notebook runs without errors when the cells are run in sequence.
# - Rename the notebook to `<roll_number>_Q2.ipynb`.
# - Fill the Name and Roll number in the below markdown

# %% [markdown]
# Name: Katha rohan reddy<br>
# Roll Number: 2020101039

# %%
# Installing Pillow Libraries
# %pip install scikit-learn matplotlib Pillow
# Out:
# Requirement already satisfied: scikit-learn in /opt/homebrew/lib/python3.10/site-packages (1.1.2)
# Requirement already satisfied: matplotlib in /opt/homebrew/lib/python3.10/site-packages (3.6.1)
# Requirement already satisfied: Pillow in /opt/homebrew/lib/python3.10/site-packages (9.2.0)
# Requirement already satisfied: scipy>=1.3.2 in /opt/homebrew/lib/python3.10/site-packages (from scikit-learn) (1.9.2)
# Requirement already satisfied: numpy>=1.17.3 in /opt/homebrew/lib/python3.10/site-packages (from scikit-learn) (1.23.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/homebrew/lib/python3.10/site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in /opt/homebrew/lib/python3.10/site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/homebrew/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/homebrew/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/lib/python3.10/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/lib/python3.10/site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/lib/python3.10/site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
#
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import os
from random import randrange
from matplotlib import pyplot as plt
from PIL import Image

# %% [markdown]
# ## Load Data

# %%
cfw_dict = {
    'Amitabhbachan': 0,
    'AamirKhan': 1,
    'DwayneJohnson': 2,
    'AishwaryaRai': 3,
    'BarackObama': 4,
    'NarendraModi': 5,
    'ManmohanSingh': 6,
    'VladimirPutin': 7
}

opt = {
    'image_size': 32,
    'is_grayscale': False,
    'val_split': 0.75
}

# %%
def load_image(path):
    im = Image.open(path).convert('L' if opt['is_grayscale'] else 'RGB')
    im = im.resize((opt['image_size'],opt['image_size']))
    im = np.array(im)
    im = im/256
    return im

def display_images(imgs,classes,row=1,col=2,w=32,h=32):
    fig=plt.figure(figsize=(8, 8))
    for i in range(1, col*row +1):
        img = imgs[i-1]
        fig.add_subplot(row, col, i)
        
        if opt['is_grayscale']:
            plt.imshow(img , cmap='gray') 
        else:
            plt.imshow(img)
        
        plt.title("Class:{}".format(classes[i-1]))
        plt.axis('off')
    plt.show()

def load_data(dir_path):
    image_list = []
    y_list = []
    label_dict = cfw_dict
    for filename in sorted(os.listdir(dir_path)):
        if filename.endswith(".png"):
            im = load_image(os.path.join(dir_path,filename))
            y = filename.split('_')[0]
            y = label_dict[y] 
            image_list.append(im)
            y_list.append(y)
        else:
            continue
    image_list = np.array(image_list)
    y_list = np.array(y_list)
    print("Dataset shape:",image_list.shape)
    print("Label shape:",y_list.shape)

    return image_list,y_list

# %%
dirpath = './IIIT-CFW/'
X,y = load_data(dirpath)
# Out:
# Dataset shape: (672, 32, 32, 3)
# Label shape: (672,)

# %%
N,H,W = X.shape[0:3]
C = 1 if opt['is_grayscale'] else X.shape[3]

ind = np.random.randint(0,y.shape[0],6)
display_images(X[ind,...],y[ind], row=2,col=3)

# %% [markdown]
# ## Dimensionality Reduction
# - Plot eigen spectrum for the data.
#
# Percentage of variance preserved is defined as the fraction of eigen values used. As we include more principal components to describe the data, the percentage of variances preserved under the dimensionality reduction increases.
#
# - Plot the percentage of variances vs the number of principal components to validate the above statement.
# - Try visualizing these eigen vectors. Comment on what these ghost faces represent
# - Try reconstructing images with your choice of number of principal components and visualize the reconstructed image.
#
# Let's define reconstruction error as the frobenius norm of the difference between original and reconstructed image.
#
# - Plot the number of principal components vs the corresponding reconstruction error for 5 selected number of principal components of your choice.
# - Using the two dominant principal values, plot the data with colors showing the labels. What do you observe?

# %% [markdown]
# #### Write a function that gives eigen values and eigen vectors given data

# %%
# write function

def eigenval(X):
    return np.linalg.eigh(X)
    
flattend_mat = np.array([i.flatten() for i in X])
flattend_mat = flattend_mat - np.mean(flattend_mat)
def pca_func(a):
    flattend_mat = np.array([i.flatten() for i in a])
    flattend_mat = flattend_mat - np.mean(flattend_mat)
    covariance_mat = np.cov(flattend_mat.T)
    eigenvalset,eigenvecset = np.linalg.eigh(covariance_mat)   
    list_x = []
    list_y = []
    io = eigenvecset
    ind_set = eigenvalset.argsort()[::-1]
    eigenvecset = eigenvecset[:,ind_set]
    eigenvalset = eigenvalset[ind_set]
    
    return eigenvecset,eigenvalset

# %% [markdown]
# #### Compute eigen values and plot eigen value spectrum

# %%
# eigen values and spectrum
eigvla,after_sort = pca_func(X)


plt.plot(after_sort,color = 'red')
plt.show()

# %% [markdown]
# #### Plot the percentage of variances vs the number of principal components

# %%
# plot variance vs components
list_x = []
list_y = []
ev,eva = pca_func(X)
total_sum = sum(eva)
for i in range(2,3072):
        list_x.append(i)
        curr_slice = after_sort[0:i+1]
        sum_var = 0
        for j in range(i):
            sum_var = sum_var + (curr_slice[j]/total_sum)*100

        list_y.append(sum_var)
plt.plot(list_x,list_y)
plt.show()

# %% [markdown]
# #### Visualize eigen faces(eigen vectors)

# %%
#Use the below sample code to visualize the eigen faces and reconstructed images (can write your own function as well)

def plot(image,H,W,C,indices):
    #indices = [randrange(100)+1 for i in range(5)]
    pl = np.reshape(image.T,(-1,H,W,C))
    plt.figure(figsize=(25,25))
    for c,i in enumerate(indices):
        ele = pl[i]
        minim = np.min(ele)
        maxim = np.max(ele)
        ele = (ele - minim) / (maxim - minim)
        ele = np.clip(ele,0,254)
        plt.subplot(1,12,c+1)
        plt.axis('off')
        plt.imshow(ele,cmap=plt.cm.gray)
    plt.show()

indices = [randrange(12)+1 for i in range(5)]
eigenvecset,eij = pca_func(X)
plot(eigenvecset,H,W,C, indices)

# %% [markdown]
# #### Reconstruction

# %%
# reconstruction



val  = 6
plot_x = []
plot_y = []
for i in range(2,25):
    eigenvecset,jui= pca_func(X)
    eigenvecset_param = eigenvecset[:i]
    pca_reduced =flattend_mat@eigenvecset_param.T
    reconstruction = pca_reduced@eigenvecset_param
    plot_x.append(i)
    plot_y.append(np.linalg.norm((reconstruction-flattend_mat)**2))

plt.plot(plot_x,plot_y)
plt.show()

# %% [markdown]
# #### Plot data in 2D

# %%
# plot data in 2D
eigenvecset_param_2 = eigenvecset[:2]
pca_2d = flattend_mat@eigenvecset_param_2.T


plt.scatter(pca_2d[:,0],pca_2d[:,1],color = 'red')
plt.show()

# %% [markdown]
# ## Lets analyze the principal components classwise
# - Visualize dominant eigen faces of each of the classes.
# - Print the number of principal components required to retain 90% variance for each of the classes and for the entire dataset
# - Are the number of components same for entire dataset and each of the classes. If yes why? If not why?
#
# Example output:
# ```
# Number of principal components required for 90% reconstruction of the:
# Entire Dataset = 10
# Amitabhbachan = 10
# AamirKhan = 10
# ...
# ```

# %%
# Load data again
X,y = load_data(dirpath)
# Out:
# Dataset shape: (672, 32, 32, 3)
# Label shape: (672,)

# %% [markdown]
# #### Visualize dominant eigen faces of each of the classes

# %%
# visualize
list_class = []
val = np.size(X,0)
print(val)
for i in range(8):
    list_class.append([])
for i in range(val):
    if(y[i] == 0):
        list_class[0].append(X[i])
    if(y[i] == 1):
        list_class[1].append(X[i])
    if(y[i] == 2):
        list_class[2].append(X[i])
    if(y[i] == 3):
        list_class[3].append(X[i])
    if(y[i] == 4):
        list_class[4].append(X[i])
    if(y[i] == 5):
        list_class[5].append(X[i])
    if(y[i] == 6):
        list_class[6].append(X[i])
    if(y[i] == 7):
        list_class[7].append(X[i])


list_eigenvectset = []
list_eigenvalset = []
for i in range(8):
    eigenvecset,kio = pca_func(list_class[i])
    list_eigenvectset.append(eigenvecset)
    list_eigenvalset.append(kio)
    plot(eigenvecset,H,W,C, indices)
#print(list_eigenvectset)
# Out:
# 672

# %% [markdown]
# #### Number of principal components required to retain 90% variance for each of the classes and for the entire dataset

# %%
# components required

list_no_of_pc = []
for i in list_eigenvalset:
    total_sum = sum(i)
    p = 0
    while True:
        
        sum_var = 0
        curr_slice = i[0:p+1]
        for j in range(p):
            sum_var = sum_var + (curr_slice[j]/total_sum)*100
        if(sum_var >= 90):
            list_no_of_pc.append(p)
            break
        p = p+1

            
print(list_no_of_pc)
# Out:
# [21, 24, 28, 36, 43, 57, 50, 44]

# %% [markdown]
# ### Eigenvalues required to get 90percentage of variance:
#
#     'Amitabhbachan':21,
#     'AamirKhan':24 ,
#     'DwayneJohnson': 28,
#     'AishwaryaRai': 36,
#     'BarackObama': 43,
#     'NarendraModi': 57,
#     'ManmohanSingh': 50,
#     'VladimirPutin': 44,
#      total : 115

# %% [markdown]
# #### Analysis : Are the number of components same for entire dataset and each of the classes. If yes why? If not why?

# %% [markdown]
# No they are not same because the dominant eigen values for some classes provide more variance and more contribution than others

# %% [markdown]
# ## Linear Regression (continued)
# 1. Perform linear regression on below datapoints
# 2. Use PCA for dimensionality reduction on this datapoints and then perform Linear regression.
# 3. Perform this experiment on different number of components and report the score for linear regression. Plot the graph of [1-200] principal components vs regression score. What do you observe?
#
# Note :- Can use inbuilt functions for Linear Regression and PCA for this question

# %%
# datapoints
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import decomposition
X,_ = load_data(dirpath)
X = X.reshape((X.shape[0],-1))
label = np.array([randrange((32*32*3)) for i in range(5)])
label = np.mean(X[:,label], axis = 1)
print(label.shape)
# Out:
# Dataset shape: (672, 32, 32, 3)
# Label shape: (672,)
# (672,)

# %%
# code here
X_train, X_test, y_train, y_test = train_test_split(X,_ , random_state=104,train_size=0.8, shuffle=True)
flattend_mat_train_nopca = [i.flatten() for i in X_train]
flattend_mat_test_nopca = [i.flatten() for i in X_test]
reg_without_pca = LinearRegression().fit(flattend_mat_train_nopca, y_train)
reg_without_pca.predict(flattend_mat_test_nopca)
print(reg_without_pca.score(flattend_mat_test_nopca,y_test))
#regre with pca 

list_regr_score = []
list_x = []
for p in range(1,200):
    flattend_mat = [i.flatten() for i in X]
    list_x.append(p)
    regr_pca = decomposition.PCA(n_components=p)
    regr_pca.fit(flattend_mat)
    flattend_mat = regr_pca.transform(flattend_mat)
    X_train, X_test, y_train, y_test = train_test_split(flattend_mat,_ , random_state=104,train_size=0.8, shuffle=True)
    reg_with_pca = LinearRegression().fit(X_train, y_train)
    list_regr_score.append(reg_with_pca.score(X_test,y_test))
    print(reg_with_pca.score(X_test,y_test))
# Out:
# -0.49480808993067016
# 0.010583805513858846
# 0.027061196331457427
# 0.11165383105363746
# 0.12110729113375462
# 0.15428521321958932
# 0.17646726895001563
# 0.19808226677213292
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [79], line 16
#      14 list_x.append(p)
#      15 regr_pca = decomposition.PCA(n_components=p)
# ---> 16 regr_pca.fit(flattend_mat)
#      17 flattend_mat = regr_pca.transform(flattend_mat)
#      18 X_train, X_test, y_train, y_test = train_test_split(flattend_mat,_ , random_state=104,train_size=0.8, shuffle=True)
#
# File /opt/homebrew/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:408, in PCA.fit(self, X, y)
#     385 """Fit the model with X.
#     386
#     387 Parameters
#    (...)
#     399     Returns the instance itself.
#     400 """
#     401 check_scalar(
#     402     self.n_oversamples,
#     403     "n_oversamples",
#     404     min_val=1,
#     405     target_type=numbers.Integral,
#     406 )
# --> 408 self._fit(X)
#     409 return self
#
# File /opt/homebrew/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:485, in PCA._fit(self, X)
#     483     return self._fit_full(X, n_components)
#     484 elif self._fit_svd_solver in ["arpack", "randomized"]:
# --> 485     return self._fit_truncated(X, n_components, self._fit_svd_solver)
#     486 else:
#     487     raise ValueError(
#     488         "Unrecognized svd_solver='{0}'".format(self._fit_svd_solver)
#     489     )
#
# File /opt/homebrew/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:606, in PCA._fit_truncated(self, X, n_components, svd_solver)
#     602     U, Vt = svd_flip(U[:, ::-1], Vt[::-1])
#     604 elif svd_solver == "randomized":
#     605     # sign flipping is done inside
# --> 606     U, S, Vt = randomized_svd(
#     607         X,
#     608         n_components=n_components,
#     609         n_oversamples=self.n_oversamples,
#     610         n_iter=self.iterated_power,
#     611         power_iteration_normalizer=self.power_iteration_normalizer,
#     612         flip_sign=True,
#     613         random_state=random_state,
#     614     )
#     616 self.n_samples_, self.n_features_ = n_samples, n_features
#     617 self.components_ = Vt
#
# File /opt/homebrew/lib/python3.10/site-packages/sklearn/utils/extmath.py:397, in randomized_svd(M, n_components, n_oversamples, n_iter, power_iteration_normalizer, transpose, flip_sign, random_state)
#     393 if transpose:
#     394     # this implementation is a bit faster with smaller shape[1]
#     395     M = M.T
# --> 397 Q = randomized_range_finder(
#     398     M,
#     399     size=n_random,
#     400     n_iter=n_iter,
#     401     power_iteration_normalizer=power_iteration_normalizer,
#     402     random_state=random_state,
#     403 )
#     405 # project M to the (k + p) dimensional space using the basis vectors
#     406 B = safe_sparse_dot(Q.T, M)
#
# File /opt/homebrew/lib/python3.10/site-packages/sklearn/utils/extmath.py:245, in randomized_range_finder(A, size, n_iter, power_iteration_normalizer, random_state)
#     241         Q, _ = linalg.qr(safe_sparse_dot(A.T, Q), mode="economic")
#     243 # Sample the range of A using by linear projection of Q
#     244 # Extract an orthonormal basis
# --> 245 Q, _ = linalg.qr(safe_sparse_dot(A, Q), mode="economic")
#     247 return Q
#
# File /opt/homebrew/lib/python3.10/site-packages/sklearn/utils/extmath.py:155, in safe_sparse_dot(a, b, dense_output)
#     151 else:
#     152     ret = a @ b
#     154 if (
# --> 155     sparse.issparse(a)
#     156     and sparse.issparse(b)
#     157     and dense_output
#     158     and hasattr(ret, "toarray")
#     159 ):
#     160     return ret.toarray()
#     161 return ret
#
# File /opt/homebrew/lib/python3.10/site-packages/scipy/sparse/_base.py:1301, in isspmatrix(x)
#    1297         else:
#    1298             return np.zeros(self.shape, dtype=self.dtype, order=order)
# -> 1301 def isspmatrix(x):
#    1302     """Is x of a sparse matrix type?
#    1303
#    1304     Parameters
#    (...)
#    1326     False
#    1327     """
#    1328     return isinstance(x, spmatrix)
#
# KeyboardInterrupt:

# %%
# analysis / plot (split the cells if required)
plt.plot(list_x,list_regr_score)
plt.show()
